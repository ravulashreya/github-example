# %%
import numpy as np
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# %%
url = 'https://en.wikipedia.org/wiki/List_of_World_Heritage_Sites_in_India'
read_table = pd.read_html(url,header=[0])
df = read_table[0]
df.head(10)
# Out:
#    Sr. No.                                 Name  Image  \
# 0        1                         Ajanta Caves    NaN
# 1        2                         Ellora Caves    NaN
# 2        3                            Agra Fort    NaN
# 3        4                            Taj Mahal    NaN
# 4        5                  Sun Temple, Konârak    NaN
# 5        6  Group of Monuments at Mahabalipuram    NaN
# 6        7              Kaziranga National Park    NaN
# 7        8             Manas Wildlife Sanctuary    NaN
# 8        9               Keoladeo National Park    NaN
# 9       10         Churches and Convents of Goa    NaN
#
#                       Region Period                  UNESCO data  \
# 0                Maharashtra    NaN    242; 1983; i, ii, iii, vi
# 1                Maharashtra    NaN      243; 1983; (i)(iii)(vi)
# 2       Uttar Pradesh, India    NaN               251; 1983; iii
# 3              Uttar Pradesh    NaN                  252; 1983;i
# 4      Puri District, Odisha    NaN       246; 1984;(i)(iii)(vi)
# 5  Mahabalipuram, Tamil Nadu    NaN  249; 1984; (i)(ii)(iii)(vi)
# 6                      Assam    NaN             337; 1985; ix, x
# 7                      Assam    NaN        338; 1985; vii, ix, x
# 8                  Rajasthan    NaN               340; 1985; (x)
# 9   Velha Goa (Old Goa), Goa    NaN      234; 1986; (ii)(iv)(vi)
#
#                                          Description
# 0  The Ajanta Caves are Budhhists caves built in ...
# 1  The Ellora Caves, also known as the Ellora Com...
# 2  The Agra Fort, also known as the Red Fort of A...
# 3  The Taj Mahal, one of the Seven Wonders of the...
# 4  The Konark Sun Temple is a 13th-century Sun Te...
# 5  The Group of Monuments at Mahabalipuram, in Ta...
# 6  Kaziranga, located in the Northeastern state o...
# 7  The Manas Wildlife Sanctuary, located in the n...
# 8  The Keoladeo National Park in Bharatpur is loc...
# 9  The Churches and Convents of Goa are monuments...

# %%
df = df.rename(index=str, columns={'Name':'Name','Region':'Region'})
df.head()
# Out:
#    Sr. No.                 Name  Image                 Region Period  \
# 0        1         Ajanta Caves    NaN            Maharashtra    NaN
# 1        2         Ellora Caves    NaN            Maharashtra    NaN
# 2        3            Agra Fort    NaN   Uttar Pradesh, India    NaN
# 3        4            Taj Mahal    NaN          Uttar Pradesh    NaN
# 4        5  Sun Temple, Konârak    NaN  Puri District, Odisha    NaN
#
#                  UNESCO data  \
# 0  242; 1983; i, ii, iii, vi
# 1    243; 1983; (i)(iii)(vi)
# 2             251; 1983; iii
# 3                252; 1983;i
# 4     246; 1984;(i)(iii)(vi)
#
#                                          Description
# 0  The Ajanta Caves are Budhhists caves built in ...
# 1  The Ellora Caves, also known as the Ellora Com...
# 2  The Agra Fort, also known as the Red Fort of A...
# 3  The Taj Mahal, one of the Seven Wonders of the...
# 4  The Konark Sun Temple is a 13th-century Sun Te...

# %%
df = df.drop(["Image","Period", "UNESCO data"], axis=1)
df.head()
# Out:
#    Sr. No.                 Name                 Region  \
# 0        1         Ajanta Caves            Maharashtra
# 1        2         Ellora Caves            Maharashtra
# 2        3            Agra Fort   Uttar Pradesh, India
# 3        4            Taj Mahal          Uttar Pradesh
# 4        5  Sun Temple, Konârak  Puri District, Odisha
#
#                                          Description
# 0  The Ajanta Caves are Budhhists caves built in ...
# 1  The Ellora Caves, also known as the Ellora Com...
# 2  The Agra Fort, also known as the Red Fort of A...
# 3  The Taj Mahal, one of the Seven Wonders of the...
# 4  The Konark Sun Temple is a 13th-century Sun Te...

# %%
df.count()
# Out:
# Sr. No.        53
# Name           53
# Region         53
# Description    53
# dtype: int64

# %%
df
# Out:
#     Sr. No.                                               Name  \
# 0         1                                       Ajanta Caves
# 1         2                                       Ellora Caves
# 2         3                                          Agra Fort
# 3         4                                          Taj Mahal
# 4         5                                Sun Temple, Konârak
# 5         6                Group of Monuments at Mahabalipuram
# 6         7                            Kaziranga National Park
# 7         8                           Manas Wildlife Sanctuary
# 8         9                             Keoladeo National Park
# 9        10                       Churches and Convents of Goa
# 10       11                       Khajuraho Group of Monuments
# 11       12                        Group of Monuments at Hampi
# 12       13                                     Fatehpur Sikri
# 13       14                   Group of Monuments at Pattadakal
# 14       15                                    Elephanta Caves
# 15       16                         Great Living Chola Temples
# 16       16                         Great Living Chola Temples
# 17       16                         Great Living Chola Temples
# 18       17                           Sundarbans National Park
# 19       18    Nanda Devi and Valley of Flowers National Parks
# 20       19                       Buddhist Monuments at Sanchi
# 21       20                              Humayun's Tomb, Delhi
# 22       21                Qutb Minar and its Monuments, Delhi
# 23       22                         Mountain Railways of India
# 24       22                         Mountain Railways of India
# 25       22                         Mountain Railways of India
# 26       23              Mahabodhi Temple Complex at Bodh Gaya
# 27       24                         Rock Shelters of Bhimbetka
# 28       25  Chhatrapati Shivaji Terminus (formerly Victori...
# 29       26             Champaner-Pavagadh Archaeological Park
# 30       27                                   Red Fort Complex
# 31       28                          The Jantar Mantar, Jaipur
# 32       29                                      Western Ghats
# 33       29                                      Western Ghats
# 34       29                                      Western Ghats
# 35       29                                      Western Ghats
# 36       29                                      Western Ghats
# 37       29                                      Western Ghats
# 38       29                                      Western Ghats
# 39       30                            Hill Forts of Rajasthan
# 40       30                            Hill Forts of Rajasthan
# 41       30                            Hill Forts of Rajasthan
# 42       30                            Hill Forts of Rajasthan
# 43       30                            Hill Forts of Rajasthan
# 44       30                            Hill Forts of Rajasthan
# 45       31                 Rani ki vav (The Queen's Stepwell)
# 46       32                      Great Himalayan National Park
# 47       33  Archaeological Site of Nalanda Mahavihara at N...
# 48       34                      Khangchendzonga National Park
# 49       35             The Architectural Work Of Le Corbusier
# 50       36                         Historic City of Ahmedabad
# 51       37      The Victorian and Art Deco Ensemble of Mumbai
# 52       38                                             Jaipur
#
#                                                Region  \
# 0                                         Maharashtra
# 1                                         Maharashtra
# 2                                Uttar Pradesh, India
# 3                                       Uttar Pradesh
# 4                               Puri District, Odisha
# 5                           Mahabalipuram, Tamil Nadu
# 6                                               Assam
# 7                                               Assam
# 8                                           Rajasthan
# 9                            Velha Goa (Old Goa), Goa
# 10                                     Madhya Pradesh
# 11                 Ballari district, Karnataka, India
# 12                                      Uttar Pradesh
# 13                Bagalkot District, Karnataka, India
# 14                                        Maharashtra
# 15  Brihadeeswarar temple, Gangaikonda Cholapuram,...
# 16  Airavateshwarar Temple, Darasuram, Tamil Nadu,...
# 17  Brihadeeswarar Temple, Thanjavur, Tamil Nadu, ...
# 18                                        West Bengal
# 19                                        Uttarakhand
# 20                              Madhya Pradesh, India
# 21                                              Delhi
# 22                                              Delhi
# 23  Darjeeling Himalayan Railway (1999), Darjeelin...
# 24  Nilgiri Mountain Railway (2005) Ooty, Tamil Na...
# 25  Kalka-Shimla Railway, Himachal Pradesh (2008)I...
# 26                                              Bihar
# 27                              Madhya Pradesh, India
# 28                                        Maharashtra
# 29                                     Gujarat, India
# 30                                              Delhi
# 31                           Jaipur, Rajasthan, India
# 32                          Agasthyamalai Sub-Cluster
# 33                                Periyar Sub-Cluster
# 34                               Anamalai Sub-Cluster
# 35                                Nilgiri Sub-Cluster
# 36           Talakaveri Sub-Cluster (five properties)
# 37            Kudremukh Sub-Cluster (five properties)
# 38                               Sahyadri Sub-Cluster
# 39                                        Chittorgarh
# 40                                        Kumbhalgarh
# 41                                       Ranthambhore
# 42                                  Amber Sub-Cluster
# 43                                          Jaisalmer
# 44                                             Gagron
# 45                              Patan, Gujarat, India
# 46                            Himachal Pradesh, India
# 47                                              Bihar
# 48                                             Sikkim
# 49                                  Chandigarh, India
# 50                                 Ahmedabad, Gujarat
# 51                                        Maharashtra
# 52                                  Jaipur, Rajasthan
#
#                                           Description
# 0   The Ajanta Caves are Budhhists caves built in ...
# 1   The Ellora Caves, also known as the Ellora Com...
# 2   The Agra Fort, also known as the Red Fort of A...
# 3   The Taj Mahal, one of the Seven Wonders of the...
# 4   The Konark Sun Temple is a 13th-century Sun Te...
# 5   The Group of Monuments at Mahabalipuram, in Ta...
# 6   Kaziranga, located in the Northeastern state o...
# 7   The Manas Wildlife Sanctuary, located in the n...
# 8   The Keoladeo National Park in Bharatpur is loc...
# 9   The Churches and Convents of Goa are monuments...
# 10  The Khajuraho Group of Monuments attributed to...
# 11  The Group of Monuments at Hampi comprise a som...
# 12  Fatehpur Sikri, "the City of Victory," was bui...
# 13  The Group of monuments in Pattadakal designate...
# 14  The Elephanta Caves are a network of sculpted ...
# 15  The Great Living Chola Temples, built by kings...
# 16  The Great Living Chola Temples, built by kings...
# 17  The Great Living Chola Temples, built by kings...
# 18  The Sundarbans National Park, the largest estu...
# 19  The Nanda Devi and Valley of Flowers National ...
# 20  The Buddhist Monuments at Sanchi, located 45 k...
# 21  Humayun's Tomb, Delhi, the first tomb built wi...
# 22  The Qutb Minar and its Monuments, Delhi, locat...
# 23  The Mountain Railways of India represent a col...
# 24  The Mountain Railways of India represent a col...
# 25  The Mountain Railways of India represent a col...
# 26  The Mahabodhi Temple Complex at Bodh Gaya (Bud...
# 27  The Rock Shelters of Bhimbetka described in th...
# 28  The Chhatrapati Shivaji Terminus is a historic...
# 29  Champaner-Pavagadh Archaeological Park is situ...
# 30  The Red Fort Complex, also known as Lal Qila i...
# 31  The Jantar Mantar in Jaipur is a collection of...
# 32  The Western Ghats, also known as the Sahyadri ...
# 33  The Western Ghats, also known as the Sahyadri ...
# 34  The Western Ghats, also known as the Sahyadri ...
# 35  The Western Ghats, also known as the Sahyadri ...
# 36  The Western Ghats, also known as the Sahyadri ...
# 37  The Western Ghats, also known as the Sahyadri ...
# 38  The Western Ghats, also known as the Sahyadri ...
# 39  The Hill Forts of Rajasthan, are a series of s...
# 40  The Hill Forts of Rajasthan, are a series of s...
# 41  The Hill Forts of Rajasthan, are a series of s...
# 42  The Hill Forts of Rajasthan, are a series of s...
# 43  The Hill Forts of Rajasthan, are a series of s...
# 44  The Hill Forts of Rajasthan, are a series of s...
# 45  Rani ki vav (The Queen's Stepwell) at Patan, G...
# 46  The Great Himalayan National Park at Kullu, Hi...
# 47  The Nalanda Mahavihara site is in the State of...
# 48  Located at the heart of the Himalayan range in...
# 49  Chosen from the work of Le Corbusier, the 17 s...
# 50  The walled city of Ahmedabad, founded by Sulta...
# 51  This is a collection of the Victorian Gothic b...
# 52  [86] The fortified city of Jaipur, in India's ...
